jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10348.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10349.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10350.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10351.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10352.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10353.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10354.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10355.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10356.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10357.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10358.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10359.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10360.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10361.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10362.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10363.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10364.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10365.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10366.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10367.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10368.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10369.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10370.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10371.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10372.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10373.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10374.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10375.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10376.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10377.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10378.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10379.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10380.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10381.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10382.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10383.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10384.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10385.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10386.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10387.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10388.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10389.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10390.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10391.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10392.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10393.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10394.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10395.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10396.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10397.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10398.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10399.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10400.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10401.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10402.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10403.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10404.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10405.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10406.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10407.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10408.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10409.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10410.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10411.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10412.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10413.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10414.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10415.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10416.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10417.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10418.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10419.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10420.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10421.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10422.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10423.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10424.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10425.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10426.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10427.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10428.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10429.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10430.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10431.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10432.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10433.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10434.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10435.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10436.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10437.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10438.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10439.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10440.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10441.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10442.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10443.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10444.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10445.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10446.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10447.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10448.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10449.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10450.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10451.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10452.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10453.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10454.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10455.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10456.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10457.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10458.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10459.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10460.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10461.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10462.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10463.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10464.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10465.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10466.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10467.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10468.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10469.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10470.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10471.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10472.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10473.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10474.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10475.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10476.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10477.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10478.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10479.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10480.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10481.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10482.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10483.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10484.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10485.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10486.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10487.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10488.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10489.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10490.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10491.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10492.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10493.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10494.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10495.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10496.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10497.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10498.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10499.jpg
#   inflating: /content/dataset/Classes/validation/vehicles/vehicles_10500.jpg

# %%
#Xception Model.  Concept of Transfer learning. Used the pretrained weights of Imagenet. I also had the image used to
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow import keras

# Check if GPUs are available
print(f"Num GPUs Available: {len(tf.config.experimental.list_physical_devices('GPU'))}")

strategy = tf.distribute.MirroredStrategy()
print(f"Number of devices: {strategy.num_replicas_in_sync}")

with strategy.scope():
    base_model = tf.keras.applications.Xception(
        input_shape=(224, 224, 3),  # Xception expects 299x299 by default, but we resize to 224x224
        weights="imagenet",
        include_top=False
    )

    base_model.trainable = False  # Freeze the base model layers

    # Added custom layers which are trainable
    x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
    x = tf.keras.layers.Dropout(0.5)(x)  # Regularization
    x = tf.keras.layers.Dense(512, activation="relu")(x)
    prediction = tf.keras.layers.Dense(3, activation="softmax")(x)

    model = tf.keras.models.Model(inputs=base_model.input, outputs=prediction)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss="categorical_crossentropy",
        metrics=['accuracy']
    )

model.summary()
# Out:
# Num GPUs Available: 1
# Number of devices: 1
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 111, 111,  │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, 111, 111,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, 111, 111,  │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 109, 109,  │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, 109, 109,  │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, 109, 109,  │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, 109, 109,  │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, 109, 109,  │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, 109, 109,  │          0 │ block2_sepconv1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, 109, 109,  │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, 109, 109,  │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 55, 55,    │      8,192 │ block1_conv2_act… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 55, 55,    │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 55, 55,    │        512 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 55, 55,    │          0 │ block2_pool[0][0… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, 55, 55,    │          0 │ add[0][0]         │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, 55, 55,    │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, 55, 55,    │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, 55, 55,    │          0 │ block3_sepconv1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, 55, 55,    │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, 55, 55,    │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 28, 28,    │     32,768 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      1,024 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 28, 28,    │          0 │ block3_pool[0][0… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, 28, 28,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, 28, 28,    │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, 28, 28,    │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, 28, 28,    │          0 │ block4_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, 28, 28,    │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, 28, 28,    │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 14, 14,    │    186,368 │ add_1[0][0]       │
# │                     │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,912 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 14, 14,    │          0 │ block4_pool[0][0… │
# │                     │ 728)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, 14, 14,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, 14, 14,    │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, 14, 14,    │          0 │ block5_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, 14, 14,    │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, 14, 14,    │          0 │ block5_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, 14, 14,    │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 14, 14,    │          0 │ block5_sepconv3_… │
# │                     │ 728)              │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, 14, 14,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, 14, 14,    │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, 14, 14,    │          0 │ block6_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, 14, 14,    │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, 14, 14,    │          0 │ block6_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, 14, 14,    │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 14, 14,    │          0 │ block6_sepconv3_… │
# │                     │ 728)              │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, 14, 14,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, 14, 14,    │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, 14, 14,    │          0 │ block7_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, 14, 14,    │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, 14, 14,    │          0 │ block7_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, 14, 14,    │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 14, 14,    │          0 │ block7_sepconv3_… │
# │                     │ 728)              │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, 14, 14,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, 14, 14,    │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, 14, 14,    │          0 │ block8_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, 14, 14,    │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, 14, 14,    │          0 │ block8_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, 14, 14,    │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 14, 14,    │          0 │ block8_sepconv3_… │
# │                     │ 728)              │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, 14, 14,    │          0 │ add_6[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, 14, 14,    │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, 14, 14,    │          0 │ block9_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, 14, 14,    │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, 14, 14,    │          0 │ block9_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, 14, 14,    │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 14, 14,    │          0 │ block9_sepconv3_… │
# │                     │ 728)              │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, 14, 14,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, 14, 14,    │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, 14, 14,    │          0 │ block10_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, 14, 14,    │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, 14, 14,    │          0 │ block10_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, 14, 14,    │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 14, 14,    │          0 │ block10_sepconv3… │
# │                     │ 728)              │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, 14, 14,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, 14, 14,    │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, 14, 14,    │          0 │ block11_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, 14, 14,    │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, 14, 14,    │          0 │ block11_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, 14, 14,    │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 14, 14,    │          0 │ block11_sepconv3… │
# │                     │ 728)              │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, 14, 14,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, 14, 14,    │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, 14, 14,    │          0 │ block12_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, 14, 14,    │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, 14, 14,    │          0 │ block12_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, 14, 14,    │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 14, 14,    │          0 │ block12_sepconv3… │
# │                     │ 728)              │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, 14, 14,    │          0 │ add_10[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, 14, 14,    │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, 14, 14,    │          0 │ block13_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, 14, 14,    │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, 14, 14,    │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 7, 7,      │    745,472 │ add_10[0][0]      │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, 7, 7,      │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7,      │      4,096 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 7, 7,      │          0 │ block13_pool[0][… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, 7, 7,      │  1,582,080 │ add_11[0][0]      │
# │ (SeparableConv2D)   │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, 7, 7,      │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, 7, 7,      │          0 │ block14_sepconv1… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, 7, 7,      │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_bn │ (None, 7, 7,      │      8,192 │ block14_sepconv2… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_a… │ (None, 7, 7,      │          0 │ block14_sepconv2… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ block14_sepconv2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │  1,049,088 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 3)         │      1,539 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,912,107 (83.59 MB)
#  Trainable params: 1,050,627 (4.01 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
#Data splitting using flow_from_directory
import tensorflow as tf
from tensorflow.keras.applications.xception import preprocess_input

datagenerator_kwargs = dict(
    preprocessing_function=preprocess_input,
)

dataflow_kwargs = dict(
    target_size=(224, 224),  # Resize all images to 224x224
    batch_size=512,
    interpolation="bilinear"  # Image resizing interpolation method
)

valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
    **datagenerator_kwargs
)

valid_generator = valid_datagenerator.flow_from_directory(
    directory='/content/dataset/Classes/validation',
    shuffle=False,
    **dataflow_kwargs
)

# Training data generator (With Augmentations). It generates data on fly
train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=30,  # Wider rotation range
    vertical_flip=True,
    horizontal_flip=True,
    width_shift_range=0.1,  # Slightly larger shift range
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.3,  # Increased zoom range
    brightness_range=[0.3, 1.7],  # Increased brightness range
    **datagenerator_kwargs
)

train_generator = train_datagenerator.flow_from_directory(
    directory='/content/dataset/Classes/train',  # Training dataset
    shuffle=True,
    **dataflow_kwargs
)
# Out:
# Found 60000 images belonging to 3 classes.
# Found 167998 images belonging to 3 classes.

# %%
# Total number of data
train_class_counts = train_generator.class_indices
print(f"Training class indices: {train_class_counts}")

train_class_counts = {class_name: 0 for class_name in train_generator.class_indices.keys()}
for class_name, class_index in train_generator.class_indices.items():
    train_class_counts[class_name] = sum(train_generator.classes == class_index)

print(f"Training data class distribution: {train_class_counts}")

valid_class_counts = valid_generator.class_indices
print(f"Validation class indices: {valid_class_counts}")

valid_class_counts = {class_name: 0 for class_name in valid_generator.class_indices.keys()}
for class_name, class_index in valid_generator.class_indices.items():
    valid_class_counts[class_name] = sum(valid_generator.classes == class_index)

print(f"Validation data class distribution: {valid_class_counts}")
# Out:
# Training class indices: {'animals': 0, 'human_faces': 1, 'vehicles': 2}
# Training data class distribution: {'animals': np.int64(25200), 'human_faces': np.int64(84000), 'vehicles': np.int64(58798)}
# Validation class indices: {'animals': 0, 'human_faces': 1, 'vehicles': 2}
# Validation data class distribution: {'animals': np.int64(9000), 'human_faces': np.int64(30000), 'vehicles': np.int64(21000)}

# %%
# Saving the callbacks i.e. best model
import os
from tensorflow.keras.callbacks import ModelCheckpoint

save_dir = '/content/drive/MyDrive/classes_models'
os.makedirs(save_dir, exist_ok=True)

checkpoint = ModelCheckpoint(
    os.path.join(save_dir, "best_model_epoch_{epoch:02d}.h5"),
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

# %%
#Early stopping 6 but of no use because trained for 1 epoch
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_accuracy", patience=6
)

# %%
#We have stopped training for second epoch as we got 99.93% accuracy on my validation data
model.fit(
              train_generator,
              epochs=30,
              validation_data=valid_generator,
              callbacks=[checkpoint,early_stop]
              # class_weight=class_weights

          )
# Out:
# Epoch 1/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9630 - loss: 0.1027
# Epoch 1: val_accuracy improved from -inf to 0.99928, saving model to /content/drive/MyDrive/classes_models/best_model_epoch_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3153s 10s/step - accuracy: 0.9631 - loss: 0.1025 - val_accuracy: 0.9993 - val_loss: 0.0031
# Epoch 2/30
#   5/329 ━━━━━━━━━━━━━━━━━━━━ 45:35 8s/step - accuracy: 0.9969 - loss: 0.0126
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-c908847d98a1> in <cell line: 0>()
# ----> 1 model.fit(
#       2               train_generator,
#       3               epochs=30,
#       4               validation_data=valid_generator,
#       5               callbacks=[checkpoint,early_stop]
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Trained model loading and making predictions, creating the test.csv as per the requirement
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.xception import preprocess_input
import tensorflow as tf
import pandas as pd
import numpy as np
import os

test_dir = '/content/dataset/Classes/test'

test_images = [os.path.join(test_dir, f) for f in os.listdir(test_dir)
              if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
df_test = pd.DataFrame({'filename': test_images})

#Create ImageDataGenerator
test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input  # Xception-specific scaling for test data
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=df_test,
    x_col='filename',
    y_col=None,  # No labels
    target_size=(224, 224),
    batch_size=1,
    shuffle=False,
    class_mode=None
)

#Loading model and predicting
model = tf.keras.models.load_model('/content/drive/MyDrive/classes_models/best_model_epoch_01.h5')
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

#Mapping to class names as keras maps the classes alphabetically
#0-animals, 1-human_faces, 2-vehicles
class_names = ['animals','human_faces','vehicles']
predicted_labels = [class_names[idx] for idx in predicted_classes]

#results DataFrame
results = pd.DataFrame({
    'image': [os.path.basename(f) for f in test_images],
    'class': predicted_labels
})

# Saving to CSV
results.to_csv('predictions.csv', index=False)
print(f"Predictions saved for {len(results)} images")
# The csv file has random images. You can cross verify the images and labels almost match by manually looking.
# Out:
# Found 12002 validated image filenames.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 12002/12002 ━━━━━━━━━━━━━━━━━━━━ 105s 8ms/step
# Predictions saved for 12002 images
